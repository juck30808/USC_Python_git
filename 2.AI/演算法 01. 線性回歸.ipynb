# %% [markdown]
# # 線性回歸 Linear regression

# %%
# 正常體位身高與體重的分布
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
bmi_health = pd.read_csv("data/500_Person_Gender_Height_Weight_Index.csv")
bmi_health_3 = bmi_health[bmi_health["Index"] == 3]
plt.plot(bmi_health_3['Height'], bmi_health_3['Weight'], "b.")
plt.show()

# %% [markdown]
# ## 直線

# %%
# 這裡先產生一份測試用的資料
import numpy as np
import matplotlib.pyplot as plt
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
# 將測試資料畫出來
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# 直線的方程式
# y = slope(斜率) * x + bias(基底)

# %%
# 測試並觀看一下直線方程式
# 可以調整 bias 與 slope 兩個值來看直線的變化
bias = 0    # 基底
slope = 1  # 斜率

theta_best = [[bias],[slope]]
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)
plt.plot(X_new, y_predict, "r-", linewidth=2)
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %%
# 將這條直線跟資料畫在一起看看
# 嘗試著調整 bias 與 slope 兩個值來讓直線貼近資料
bias = 0    # 基底
slope = 1  # 斜率

X_b = np.c_[np.ones((100, 1)), X]  # add x0 = 1 to each instance
theta_best = [[bias],[slope]]
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# ## 如何進行線性回歸計算?
# 參考資料:
# * [維基百科](https://zh.wikipedia.org/wiki/%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8)
# * [線性回歸(Linear Regression)](https://medium.com/@chih.sheng.huang821/%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8-linear-regression-3a271a7453e)
# * [古典線性迴歸模型](https://mropengate.blogspot.com/2015/11/probability-and-statistics-introduction.html)
#
# ### 概念
# 尋找一條直線使得所有資料點到這條直線的誤差的平方總和最小
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png "線性回歸的誤差方程式")

# %%
# 用線性回歸的方程式來計算正確的直線
X_b = np.c_[np.ones((100, 1)), X]  # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# ## 多元回歸(multiple regression)
# 當資料的欄位不只一個時建立的線性回歸就稱為多元回歸
#
# y = w1*x1 + w2*x2 + ....... + wn*xn + b
# * y : 預測值
# * x1 ~ xn : 每個欄位的值
# * w1 ~ wn : 每個欄位的斜率
# * b : 基底
#
# w1~wn是每個欄位(項度)的斜率，也可以看成是每個欄位對於預測輸出的重要性

# %% [markdown]
# ## 線性回歸的問題
#
# * 遇到非線性資料預測會失準
# * 會受到離異值的影響
#
# ![image.png](attachment:image.png)
